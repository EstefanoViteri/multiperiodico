# %%
import random
random.seed(0)

# %%
n_preventas = 10
min_recetas = 1
max_recetas = 5
min_tallos = 1
max_tallos = 24
min_bunches = 1
max_bunches = 24
min_boxes = 10
max_boxes = 100
min_flores = 1
max_flores = 5
flores = ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'M']
colores = ['α', 'β', 'γ', 'δ', 'ε', 'ζ', 'η', 'θ', 'ι', 'κ', 'λ', 'μ', 'ν']
grados = ['40','50','60']
variedades = ['Λ', 'Γ', 'Ξ', 'Ο', 'Π', 'Ρ', 'Σ', 'Τ', 'Υ', 'Φ', 'Χ', 'Ψ', 'Ω']
tipos_de_caja = ['F','H','E','T']

dem = dict()
dem_info = dict()
sur_original ='Surtido 0'
for i in range(1,n_preventas+1):
    nom_prev ='Preventa_{}'.format(i)
    dem[nom_prev] = {sur_original: dict()}
    dem_info[nom_prev] = {'FechaUP': random.randint(1, 15),
                          'Boxes': random.randint(min_boxes, max_boxes),
                          'BoxCode': tipos_de_caja[random.randint(0, 3)],
                          #'Pack': ,
                          'Adelanto_max': random.randint(1, 2),
                          'Receta_info': dict()}
    num_recetas = random.randint(min_recetas, max_recetas)
    for j in range(1,num_recetas+1):
        nom_rec = 'Receta_{}'.format(j)
        num_flores = random.randint(min_flores, max_flores)
        
        dem[nom_prev][sur_original][nom_rec] = {
            (a,flores[random.randint(0, 12)],
             colores[random.randint(0, 12)],
             grados[random.randint(0, 2)],
             variedades[random.randint(0, 12)]) 
            for a in range(1,num_flores+1)}
        
        dem_info[nom_prev]['Receta_info'][nom_rec] = {
            'Bunches': random.randint(min_bunches, max_bunches),
            'Flores_info': dict()
        }
        for k in dem[nom_prev][sur_original][nom_rec]:
            dem_info[nom_prev]['Receta_info'][nom_rec]['Flores_info'][k] = {
                'Tallos': random.randint(min_tallos,max_tallos)
            }

# %%
dem
# Out:
# {'Preventa_1': {'Surtido 0': {'Receta_1': {(1, 'F', 'μ', '50', 'Ξ'),
#     (2, 'A', 'δ', '50', 'Ρ'),
#     (3, 'H', 'ε', '50', 'Υ'),
#     (4, 'K', 'ζ', '40', 'Φ')}}},
#  'Preventa_2': {'Surtido 0': {'Receta_1': {(1, 'I', 'δ', '40', 'Ω'),
#     (2, 'C', 'ε', '50', 'Σ'),
#     (3, 'K', 'α', '40', 'Φ')},
#    'Receta_2': {(1, 'C', 'η', '50', 'Υ')}}},
#  'Preventa_3': {'Surtido 0': {'Receta_1': {(1, 'D', 'θ', '60', 'Ρ')},
#    'Receta_2': {(1, 'G', 'η', '40', 'Σ')},
#    'Receta_3': {(1, 'D', 'ζ', '50', 'Τ'),
#     (2, 'B', 'γ', '40', 'Π'),
#     (3, 'B', 'ι', '60', 'Ψ'),
#     (4, 'C', 'ν', '60', 'Τ')}}},
#  'Preventa_4': {'Surtido 0': {'Receta_1': {(1, 'K', 'λ', '40', 'Τ'),
#     (2, 'M', 'δ', '50', 'Λ'),
#     (3, 'L', 'θ', '60', 'Τ'),
#     (4, 'A', 'δ', '50', 'Γ')},
#    'Receta_2': {(1, 'L', 'ν', '50', 'Γ'),
#     (2, 'K', 'θ', '40', 'Υ'),
#     (3, 'M', 'η', '50', 'Χ'),
#     (4, 'A', 'β', '50', 'Χ')},
#    'Receta_3': {(1, 'L', 'η', '50', 'Γ'),
#     (2, 'L', 'ε', '50', 'Π'),
#     (3, 'M', 'λ', '40', 'Φ'),
#     (4, 'B', 'α', '40', 'Ω'),
#     (5, 'E', 'ε', '60', 'Ρ')}}},
#  'Preventa_5': {'Surtido 0': {'Receta_1': {(1, 'K', 'δ', '60', 'Γ'),
#     (2, 'G', 'λ', '60', 'Σ'),
#     (3, 'L', 'ν', '50', 'Π'),
#     (4, 'H', 'ζ', '60', 'Χ'),
#     (5, 'C', 'γ', '40', 'Ψ')},
#    'Receta_2': {(1, 'K', 'ε', '50', 'Χ'),
#     (2, 'H', 'μ', '50', 'Ο'),
#     (3, 'H', 'θ', '60', 'Υ'),
#     (4, 'F', 'θ', '60', 'Λ'),
#     (5, 'H', 'ε', '40', 'Ψ')},
#    'Receta_3': {(1, 'G', 'α', '60', 'Γ'),
#     (2, 'K', 'β', '60', 'Ψ'),
#     (3, 'K', 'η', '40', 'Ρ'),
#     (4, 'A', 'β', '60', 'Λ')},
#    'Receta_4': {(1, 'C', 'ν', '60', 'Π'), (2, 'D', 'β', '50', 'Τ')},
#    'Receta_5': {(1, 'F', 'η', '60', 'Χ'), (2, 'G', 'γ', '50', 'Ψ')}}},
#  'Preventa_6': {'Surtido 0': {'Receta_1': {(1, 'G', 'ν', '50', 'Σ'),
#     (2, 'L', 'δ', '40', 'Τ'),
#     (3, 'D', 'κ', '60', 'Λ'),
#     (4, 'G', 'α', '40', 'Χ')},
#    'Receta_2': {(1, 'D', 'κ', '50', 'Φ'), (2, 'B', 'μ', '60', 'Ω')},
#    'Receta_3': {(1, 'A', 'λ', '60', 'Υ'),
#     (2, 'K', 'λ', '60', 'Ψ'),
#     (3, 'G', 'κ', '50', 'Τ'),
#     (4, 'E', 'μ', '50', 'Ο')}}},
#  'Preventa_7': {'Surtido 0': {'Receta_1': {(1, 'B', 'ν', '50', 'Χ'),
#     (2, 'D', 'κ', '50', 'Υ')}}},
#  'Preventa_8': {'Surtido 0': {'Receta_1': {(1, 'I', 'θ', '50', 'Π'),
#     (2, 'A', 'ι', '40', 'Ο'),
#     (3, 'F', 'β', '40', 'Υ')},
#    'Receta_2': {(1, 'E', 'ι', '50', 'Π'),
#     (2, 'H', 'ζ', '60', 'Ο'),
#     (3, 'A', 'ε', '60', 'Γ')},
#    'Receta_3': {(1, 'A', 'ν', '50', 'Τ'),
#     (2, 'H', 'θ', '40', 'Γ'),
#     (3, 'B', 'δ', '40', 'Ω'),
#     (4, 'C', 'η', '40', 'Τ')}}},
#  'Preventa_9': {'Surtido 0': {'Receta_1': {(1, 'E', 'ζ', '50', 'Σ'),
#     (2, 'B', 'ι', '50', 'Φ')},
#    'Receta_2': {(1, 'M', 'θ', '60', 'Φ'),
#     (2, 'H', 'ι', '60', 'Π'),
#     (3, 'E', 'δ', '40', 'Γ')}}},
#  'Preventa_10': {'Surtido 0': {'Receta_1': {(1, 'L', 'ι', '60', 'Σ')},
#    'Receta_2': {(1, 'K', 'ε', '40', 'Ψ'),
#     (2, 'J', 'ζ', '40', 'Χ'),
#     (3, 'L', 'μ', '60', 'Χ'),
#     (4, 'E', 'δ', '60', 'Ο')},
#    'Receta_3': {(1, 'F', 'λ', '50', 'Π'), (2, 'J', 'γ', '40', 'Ω')}}}}

# %%
#dem_info
# Out:
# {'Preventa_1': {'FechaUP': 4,
#   'Boxes': 28,
#   'BoxCode': 'H',
#   'Adelanto_max': 2,
#   'Receta_info': {'Receta_1': {'Bunches': 3,
#     'Flores_info': {(2, 'A', 'δ', '50', 'Ρ'): {'Tallos': 4},
#      (4, 'K', 'ζ', '40', 'Φ'): {'Tallos': 18},
#      (1, 'F', 'μ', '50', 'Ξ'): {'Tallos': 19},
#      (3, 'H', 'ε', '50', 'Υ'): {'Tallos': 10}}}}},
#  'Preventa_2': {'FechaUP': 3,
#   'Boxes': 58,
#   'BoxCode': 'H',
#   'Adelanto_max': 1,
#   'Receta_info': {'Receta_1': {'Bunches': 1,
#     'Flores_info': {(3, 'K', 'α', '40', 'Φ'): {'Tallos': 13},
#      (2, 'C', 'ε', '50', 'Σ'): {'Tallos': 3},
#      (1, 'I', 'δ', '40', 'Ω'): {'Tallos': 23}}},
#    'Receta_2': {'Bunches': 14,
#     'Flores_info': {(1, 'C', 'η', '50', 'Υ'): {'Tallos': 24}}}}},
#  'Preventa_3': {'FechaUP': 15,
#   'Boxes': 28,
#   'BoxCode': 'T',
#   'Adelanto_max': 2,
#   'Receta_info': {'Receta_1': {'Bunches': 21,
#     'Flores_info': {(1, 'D', 'θ', '60', 'Ρ'): {'Tallos': 17}}},
#    'Receta_2': {'Bunches': 24,
#     'Flores_info': {(1, 'G', 'η', '40', 'Σ'): {'Tallos': 11}}},
#    'Receta_3': {'Bunches': 13,
#     'Flores_info': {(3, 'B', 'ι', '60', 'Ψ'): {'Tallos': 6},
#      (1, 'D', 'ζ', '50', 'Τ'): {'Tallos': 14},
#      (2, 'B', 'γ', '40', 'Π'): {'Tallos': 14},
#      (4, 'C', 'ν', '60', 'Τ'): {'Tallos': 6}}}}},
#  'Preventa_4': {'FechaUP': 4,
#   'Boxes': 68,
#   'BoxCode': 'E',
#   'Adelanto_max': 1,
#   'Receta_info': {'Receta_1': {'Bunches': 21,
#     'Flores_info': {(3, 'L', 'θ', '60', 'Τ'): {'Tallos': 10},
#      (2, 'M', 'δ', '50', 'Λ'): {'Tallos': 18},
#      (1, 'K', 'λ', '40', 'Τ'): {'Tallos': 20},
#      (4, 'A', 'δ', '50', 'Γ'): {'Tallos': 5}}},
#    'Receta_2': {'Bunches': 2,
#     'Flores_info': {(1, 'L', 'ν', '50', 'Γ'): {'Tallos': 1},
#      (3, 'M', 'η', '50', 'Χ'): {'Tallos': 9},
#      (2, 'K', 'θ', '40', 'Υ'): {'Tallos': 13},
#      (4, 'A', 'β', '50', 'Χ'): {'Tallos': 17}}},
#    'Receta_3': {'Bunches': 4,
#     'Flores_info': {(4, 'B', 'α', '40', 'Ω'): {'Tallos': 17},
#      (1, 'L', 'η', '50', 'Γ'): {'Tallos': 8},
#      (3, 'M', 'λ', '40', 'Φ'): {'Tallos': 6},
#      (2, 'L', 'ε', '50', 'Π'): {'Tallos': 3},
#      (5, 'E', 'ε', '60', 'Ρ'): {'Tallos': 14}}}}},
#  'Preventa_5': {'FechaUP': 14,
#   'Boxes': 47,
#   'BoxCode': 'E',
#   'Adelanto_max': 1,
#   'Receta_info': {'Receta_1': {'Bunches': 4,
#     'Flores_info': {(4, 'H', 'ζ', '60', 'Χ'): {'Tallos': 13},
#      (1, 'K', 'δ', '60', 'Γ'): {'Tallos': 13},
#      (3, 'L', 'ν', '50', 'Π'): {'Tallos': 19},
#      (5, 'C', 'γ', '40', 'Ψ'): {'Tallos': 15},
#      (2, 'G', 'λ', '60', 'Σ'): {'Tallos': 5}}},
#    'Receta_2': {'Bunches': 16,
#     'Flores_info': {(4, 'F', 'θ', '60', 'Λ'): {'Tallos': 2},
#      (5, 'H', 'ε', '40', 'Ψ'): {'Tallos': 20},
#      (2, 'H', 'μ', '50', 'Ο'): {'Tallos': 7},
#      (1, 'K', 'ε', '50', 'Χ'): {'Tallos': 1},
#      (3, 'H', 'θ', '60', 'Υ'): {'Tallos': 12}}},
#    'Receta_3': {'Bunches': 9,
#     'Flores_info': {(1, 'G', 'α', '60', 'Γ'): {'Tallos': 21},
#      (2, 'K', 'β', '60', 'Ψ'): {'Tallos': 23},
#      (4, 'A', 'β', '60', 'Λ'): {'Tallos': 10},
#      (3, 'K', 'η', '40', 'Ρ'): {'Tallos': 24}}},
#    'Receta_4': {'Bunches': 23,
#     'Flores_info': {(1, 'C', 'ν', '60', 'Π'): {'Tallos': 11},
#      (2, 'D', 'β', '50', 'Τ'): {'Tallos': 13}}},
#    'Receta_5': {'Bunches': 5,
#     'Flores_info': {(2, 'G', 'γ', '50', 'Ψ'): {'Tallos': 17},
#      (1, 'F', 'η', '60', 'Χ'): {'Tallos': 11}}}}},
#  'Preventa_6': {'FechaUP': 3,
#   'Boxes': 36,
#   'BoxCode': 'H',
#   'Adelanto_max': 2,
#   'Receta_info': {'Receta_1': {'Bunches': 3,
#     'Flores_info': {(4, 'G', 'α', '40', 'Χ'): {'Tallos': 6},
#      (3, 'D', 'κ', '60', 'Λ'): {'Tallos': 12},
#      (2, 'L', 'δ', '40', 'Τ'): {'Tallos': 2},
#      (1, 'G', 'ν', '50', 'Σ'): {'Tallos': 24}}},
#    'Receta_2': {'Bunches': 10,
#     'Flores_info': {(2, 'B', 'μ', '60', 'Ω'): {'Tallos': 12},
#      (1, 'D', 'κ', '50', 'Φ'): {'Tallos': 14}}},
#    'Receta_3': {'Bunches': 11,
#     'Flores_info': {(4, 'E', 'μ', '50', 'Ο'): {'Tallos': 9},
#      (1, 'A', 'λ', '60', 'Υ'): {'Tallos': 2},
#      (3, 'G', 'κ', '50', 'Τ'): {'Tallos': 2},
#      (2, 'K', 'λ', '60', 'Ψ'): {'Tallos': 2}}}}},
#  'Preventa_7': {'FechaUP': 3,
#   'Boxes': 54,
#   'BoxCode': 'F',
#   'Adelanto_max': 2,
#   'Receta_info': {'Receta_1': {'Bunches': 8,
#     'Flores_info': {(2, 'D', 'κ', '50', 'Υ'): {'Tallos': 15},
#      (1, 'B', 'ν', '50', 'Χ'): {'Tallos': 7}}}}},
#  'Preventa_8': {'FechaUP': 6,
#   'Boxes': 87,
#   'BoxCode': 'F',
#   'Adelanto_max': 1,
#   'Receta_info': {'Receta_1': {'Bunches': 12,
#     'Flores_info': {(1, 'I', 'θ', '50', 'Π'): {'Tallos': 7},
#      (3, 'F', 'β', '40', 'Υ'): {'Tallos': 7},
#      (2, 'A', 'ι', '40', 'Ο'): {'Tallos': 9}}},
#    'Receta_2': {'Bunches': 1,
#     'Flores_info': {(1, 'E', 'ι', '50', 'Π'): {'Tallos': 15},
#      (2, 'H', 'ζ', '60', 'Ο'): {'Tallos': 16},
#      (3, 'A', 'ε', '60', 'Γ'): {'Tallos': 24}}},
#    'Receta_3': {'Bunches': 20,
#     'Flores_info': {(4, 'C', 'η', '40', 'Τ'): {'Tallos': 3},
#      (3, 'B', 'δ', '40', 'Ω'): {'Tallos': 14},
#      (1, 'A', 'ν', '50', 'Τ'): {'Tallos': 18},
#      (2, 'H', 'θ', '40', 'Γ'): {'Tallos': 13}}}}},
#  'Preventa_9': {'FechaUP': 1,
#   'Boxes': 33,
#   'BoxCode': 'H',
#   'Adelanto_max': 2,
#   'Receta_info': {'Receta_1': {'Bunches': 18,
#     'Flores_info': {(1, 'E', 'ζ', '50', 'Σ'): {'Tallos': 7},
#      (2, 'B', 'ι', '50', 'Φ'): {'Tallos': 23}}},
#    'Receta_2': {'Bunches': 20,
#     'Flores_info': {(3, 'E', 'δ', '40', 'Γ'): {'Tallos': 23},
#      (1, 'M', 'θ', '60', 'Φ'): {'Tallos': 4},
#      (2, 'H', 'ι', '60', 'Π'): {'Tallos': 6}}}}},
#  'Preventa_10': {'FechaUP': 12,
#   'Boxes': 63,
#   'BoxCode': 'H',
#   'Adelanto_max': 1,
#   'Receta_info': {'Receta_1': {'Bunches': 2,
#     'Flores_info': {(1, 'L', 'ι', '60', 'Σ'): {'Tallos': 4}}},
#    'Receta_2': {'Bunches': 3,
#     'Flores_info': {(2, 'J', 'ζ', '40', 'Χ'): {'Tallos': 17},
#      (4, 'E', 'δ', '60', 'Ο'): {'Tallos': 10},
#      (1, 'K', 'ε', '40', 'Ψ'): {'Tallos': 22},
#      (3, 'L', 'μ', '60', 'Χ'): {'Tallos': 11}}},
#    'Receta_3': {'Bunches': 1,
#     'Flores_info': {(2, 'J', 'γ', '40', 'Ω'): {'Tallos': 18},
#      (1, 'F', 'λ', '50', 'Π'): {'Tallos': 17}}}}}}
